# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('D:\data sets\Telco_customer_churn.xlsx')

# %%
df.head(3)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
#
#   Paperless Billing    Payment Method  Monthly Charges Total Charges  \
# 0               Yes      Mailed check            53.85        108.15
# 1               Yes  Electronic check            70.70        151.65
# 2               Yes  Electronic check            99.65         820.5
#
#   Churn Label Churn Value Churn Score  CLTV                  Churn Reason
# ...

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
df['Churn Reason']=df['Churn Reason'].replace(np.nan,'not_defined')

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# Count                0
# Country              0
# State                0
# City                 0
# Zip Code             0
# Lat Long             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure Months        0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn Label          0
# Churn Value          0
# Churn Score          0
# CLTV                 0
# Churn Reason         0
# dtype: int64

# %%
df.describe()
# Out:
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Churn Value  Churn Score         CLTV
# count      7043.000000  7043.000000  7043.000000  7043.000000
# mean         64.761692     0.265370    58.699418  4400.295755
# std          30.090047     0.441561    21.525131  1183.057152
# min          18.250000     0.000000     5.000000  2003.000000
# ...

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'Two year', 'One year'], dtype=object)

# %%
df['Streaming Movies'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['Streaming TV'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['Streaming TV'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['Tech Support'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['Device Protection'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['Online Backup'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df['Online Security'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df['Internet Service'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df['Multiple Lines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %%
df['Phone Service'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Paperless Billing'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Churn Label'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Partner'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Churn Value'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# # data preparation

# %% [markdown]
# #converting  yes, no to 01

# %%
l1=['Phone Service', 'Paperless Billing', 'Churn Label', 'Partner', 'Dependents']
def binary_map(x):
    return x.map({'Yes':1,'No':0})
df[l1]=df[l1].apply(binary_map)

# %%
df

# %%
dib['Diabetes'] = dib['Diabetes'].map({'Yes': 1, 'No': 0})

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
#    Paperless Billing             Payment Method  Monthly Charges  \
# ...

# %% [markdown]
# # create dummy

# %%
dummy=pd.get_dummies(df[['Gender','Payment Method','Internet Service','Contract']],drop_first=True)

# %%
df=pd.concat([df,dummy],axis=1)

# %%
ml = pd.get_dummies(df['Multiple Lines'], prefix='MultipleLines')

# %%
ml1 = ml.drop(['MultipleLines_No phone service'], 1)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\4070569834.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   ml1 = ml.drop(['MultipleLines_No phone service'], 1)

# %%
ml1
# Out:
#       MultipleLines_No  MultipleLines_Yes
# 0                    1                  0
# 1                    1                  0
# 2                    0                  1
# 3                    0                  1
# 4                    0                  1
# ...                ...                ...
# 7038                 1                  0
# 7039                 0                  1
# 7040                 0                  1
# 7041                 0                  0
# 7042                 1                  0
#
# [7043 rows x 2 columns]

# %%
df=pd.concat([df,ml1],axis=1)

# %%
os = pd.get_dummies(df['Online Security'], prefix='Online Security')
os1 = os.drop(['Online Security_No internet service'], 1)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\3019937821.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   os1 = os.drop(['Online Security_No internet service'], 1)

# %%
os1
# Out:
#       Online Security_No  Online Security_Yes
# 0                      0                    1
# 1                      1                    0
# 2                      1                    0
# 3                      1                    0
# 4                      1                    0
# ...                  ...                  ...
# 7038                   0                    0
# 7039                   0                    1
# 7040                   1                    0
# 7041                   0                    1
# 7042                   0                    1
#
# [7043 rows x 2 columns]

# %%
df=pd.concat([df,os1],axis=1)

# %%
ob = pd.get_dummies(df['Online Backup'], prefix='Online Backup')
ob1 = ob.drop(['Online Backup_No internet service'], 1)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\2047994647.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   ob1 = ob.drop(['Online Backup_No internet service'], 1)

# %%
ob1
# Out:
#       Online Backup_No  Online Backup_Yes
# 0                    0                  1
# 1                    1                  0
# 2                    1                  0
# 3                    1                  0
# 4                    0                  1
# ...                ...                ...
# 7038                 0                  0
# 7039                 1                  0
# 7040                 0                  1
# 7041                 1                  0
# 7042                 1                  0
#
# [7043 rows x 2 columns]

# %%
df=pd.concat([df,ob1],axis=1)

# %%
dp = pd.get_dummies(df['Device Protection'], prefix='Device Protection')
dp1 = dp.drop(['Device Protection_No internet service'], 1)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\3734081694.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   dp1 = dp.drop(['Device Protection_No internet service'], 1)

# %%
df=pd.concat([df,dp1],axis=1)

# %%
ts = pd.get_dummies(df['Tech Support'], prefix='TechSupport')
ts1 = ts.drop(['TechSupport_No internet service'], 1)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\1254776265.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   ts1 = ts.drop(['TechSupport_No internet service'], 1)

# %%
df=pd.concat([df,ts1],axis=1)

# %%
st =pd.get_dummies(df['Streaming TV'], prefix='StreamingTV')
st1 = st.drop(['StreamingTV_No internet service'], 1)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\423744618.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   st1 = st.drop(['StreamingTV_No internet service'], 1)

# %%
st1
# Out:
#       StreamingTV_No  StreamingTV_Yes
# 0                  1                0
# 1                  1                0
# 2                  0                1
# 3                  0                1
# 4                  0                1
# ...              ...              ...
# 7038               0                0
# 7039               0                1
# 7040               0                1
# 7041               1                0
# 7042               0                1
#
# [7043 rows x 2 columns]

# %%
df=pd.concat([df,st1],axis=1)

# %%
sm = pd.get_dummies(df['Streaming Movies'], prefix='StreamingMovies')
sm1 = sm.drop(['StreamingMovies_No internet service'], 1)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\1681239305.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   sm1 = sm.drop(['StreamingMovies_No internet service'], 1)

# %%
df=pd.concat([df,sm1],axis=1)

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...
#
#   Online Backup_No  Online Backup_Yes  Device Protection_No  \
# 0                0                  1                     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 55 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   CustomerID                              7043 non-null   object
#  1   Count                                   7043 non-null   int64
#  2   Country                                 7043 non-null   object
#  3   State                                   7043 non-null   object
#  4   City                                    7043 non-null   object
#  5   Zip Code                                7043 non-null   int64
#  6   Lat Long                                7043 non-null   object
#  7   Latitude                                7043 non-null   float64
#  8   Longitude                               7043 non-null   float64
#  9   Gender                                  7043 non-null   object
# ...

# %% [markdown]
# # droping duplicates column

# %%
df= df.drop(['Contract','Payment Method','Gender','Multiple Lines','Internet Service', 'Online Security', 'Online Backup', 'Device Protection',
       'Tech Support', 'Streaming TV', 'Streaming Movies'], 1)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\3701838254.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df= df.drop(['Contract','Payment Method','Gender','Multiple Lines','Internet Service', 'Online Security', 'Online Backup', 'Device Protection',

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 44 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   CustomerID                              7043 non-null   object
#  1   Count                                   7043 non-null   int64
#  2   Country                                 7043 non-null   object
#  3   State                                   7043 non-null   object
#  4   City                                    7043 non-null   object
#  5   Zip Code                                7043 non-null   int64
#  6   Lat Long                                7043 non-null   object
#  7   Latitude                                7043 non-null   float64
#  8   Longitude                               7043 non-null   float64
#  9   Senior Citizen                          7043 non-null   object
# ...

# %% [markdown]
# # how do we change object to int???

# %%
df['Total Charges']=df['Total Charges'].convert_objects(convert_numeric=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df['Total Charges']=df['Total Charges'].convert_objects(convert_numeric=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'convert_objects'

# %%
df['Lat Long']
# Out:
# 0       33.964131, -118.272783
# 1        34.059281, -118.30742
# 2       34.048013, -118.293953
# 3       34.062125, -118.315709
# 4       34.039224, -118.266293
#                  ...
# 7038    34.341737, -116.539416
# 7039    34.667815, -117.536183
# 7040    34.559882, -115.637164
# 7041       34.1678, -116.86433
# 7042    34.424926, -117.184503
# Name: Lat Long, Length: 7043, dtype: object

# %% [markdown]
# # checking for outliers

# %%
l3=df[['Latitude','Longitude','Churn Score','CLTV','Monthly Charges','Total Charges']]
l3.describe(percentiles=[.25, .5, .75, .90, .95, .99])
# Out:
#           Latitude    Longitude  Churn Score         CLTV  Monthly Charges
# count  7043.000000  7043.000000  7043.000000  7043.000000      7043.000000
# mean     36.282441  -119.798880    58.699418  4400.295755        64.761692
# std       2.455723     2.157889    21.525131  1183.057152        30.090047
# min      32.555828  -124.301372     5.000000  2003.000000        18.250000
# 25%      34.030915  -121.815412    40.000000  3469.000000        35.500000
# 50%      36.391777  -119.730885    61.000000  4527.000000        70.350000
# 75%      38.224869  -118.043237    75.000000  5380.500000        89.850000
# 90%      39.532220  -117.127409    87.000000  5864.800000       102.600000
# 95%      40.557314  -116.760580    94.000000  6087.000000       107.400000
# 99%      41.583700  -115.516984    99.000000  6424.580000       114.729000
# max      41.962127  -114.192901   100.000000  6500.000000       118.750000

# %%
df.isnull().sum()
# Out:
# CustomerID                                0
# Count                                     0
# Country                                   0
# State                                     0
# City                                      0
# Zip Code                                  0
# Lat Long                                  0
# Latitude                                  0
# Longitude                                 0
# Senior Citizen                            0
# Partner                                   0
# Dependents                                0
# Tenure Months                             0
# Phone Service                             0
# Paperless Billing                         0
# Monthly Charges                           0
# Total Charges                             0
# Churn Label                               0
# Churn Value                               0
# Churn Score                               0
# CLTV                                      0
# ...

# %% [markdown]
# # percentage of null value

# %%
round(100*(df.isnull().sum()/len(df)),2)
# Out:
# CustomerID                                0.0
# Count                                     0.0
# Country                                   0.0
# State                                     0.0
# City                                      0.0
# Zip Code                                  0.0
# Lat Long                                  0.0
# Latitude                                  0.0
# Longitude                                 0.0
# Senior Citizen                            0.0
# Partner                                   0.0
# Dependents                                0.0
# Tenure Months                             0.0
# Phone Service                             0.0
# Paperless Billing                         0.0
# Monthly Charges                           0.0
# Total Charges                             0.0
# Churn Label                               0.0
# Churn Value                               0.0
# Churn Score                               0.0
# ...

# %% [markdown]
# # test train split

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['Churn Label','Churn Value','CustomerID','Country','City','State','Churn Reason'],axis=1)
x.head()
# Out:
#    Count  Zip Code                Lat Long   Latitude   Longitude  \
# 0      1     90003  33.964131, -118.272783  33.964131 -118.272783
# 1      1     90005   34.059281, -118.30742  34.059281 -118.307420
# 2      1     90006  34.048013, -118.293953  34.048013 -118.293953
# 3      1     90010  34.062125, -118.315709  34.062125 -118.315709
# 4      1     90015  34.039224, -118.266293  34.039224 -118.266293
#
#   Senior Citizen  Partner  Dependents  Tenure Months  Phone Service  ...  \
# 0             No        0           0              2              1  ...
# 1             No        0           1              2              1  ...
# 2             No        0           1              8              1  ...
# 3             No        1           1             28              1  ...
# 4             No        0           1             49              1  ...
#
#    Online Backup_No  Online Backup_Yes Device Protection_No  \
# 0                 0                  1                    1
# ...

# %%
x=x.drop(['Lat Long','Total Charges'],axis=1)

# %%
x.head()
# Out:
#    Count  Zip Code   Latitude   Longitude Senior Citizen  Partner  Dependents  \
# 0      1     90003  33.964131 -118.272783             No        0           0
# 1      1     90005  34.059281 -118.307420             No        0           1
# 2      1     90006  34.048013 -118.293953             No        0           1
# 3      1     90010  34.062125 -118.315709             No        1           1
# 4      1     90015  34.039224 -118.266293             No        0           1
#
#    Tenure Months  Phone Service  Paperless Billing  ...  Online Backup_No  \
# 0              2              1                  1  ...                 0
# 1              2              1                  1  ...                 1
# 2              8              1                  1  ...                 1
# 3             28              1                  1  ...                 1
# 4             49              1                  1  ...                 0
#
# ...

# %%
y=df['Churn Value']
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Churn Value, dtype: int64

# %% [markdown]
# # split the data into train and test

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,train_size=0.7,random_state=0)

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4930 entries, 3580 to 2732
# Data columns (total 35 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Count                                   4930 non-null   int64
#  1   Zip Code                                4930 non-null   int64
#  2   Latitude                                4930 non-null   float64
#  3   Longitude                               4930 non-null   float64
#  4   Senior Citizen                          4930 non-null   object
#  5   Partner                                 4930 non-null   int64
#  6   Dependents                              4930 non-null   int64
#  7   Tenure Months                           4930 non-null   int64
#  8   Phone Service                           4930 non-null   int64
#  9   Paperless Billing                       4930 non-null   int64
# ...

# %%
scaler=StandardScaler()
x_train[['Tenure Months','Monthly Charges']] = scaler.fit_transform(x_train[['Tenure Months','Monthly Charges']])

x_train.head()
# Out:
#       Count  Zip Code   Latitude   Longitude Senior Citizen  Partner  \
# 3580      1     93254  34.956577 -119.750142             No        1
# 2364      1     93240  35.607875 -118.466318             No        0
# 6813      1     90505  33.807882 -118.347957             No        1
# 789       1     95636  38.636102 -120.522149             No        1
# 561       1     92338  34.702766 -116.093376             No        0
#
#       Dependents  Tenure Months  Phone Service  Paperless Billing  ...  \
# 3580           1      -1.156054              1                  1  ...
# 2364           0      -1.278321              1                  0  ...
# 6813           0       1.615327              1                  0  ...
# 789            0      -0.381697              1                  1  ...
# 561            0      -1.196809              1                  0  ...
#
#       Online Backup_No  Online Backup_Yes  Device Protection_No  \
# ...

# %%
x_train[['Latitude','Longitude']] = scaler.fit_transform(x_train[['Latitude','Longitude']])

x_train.head()
# Out:
#       Count  Zip Code  Latitude  Longitude Senior Citizen  Partner  \
# 3580      1     93254 -0.545284   0.026094             No        1
# 2364      1     93240 -0.280890   0.622321             No        0
# 6813      1     90505 -1.011596   0.677289             No        1
# 789       1     95636  0.948415  -0.332437             No        1
# 561       1     92338 -0.648318   1.724348             No        0
#
#       Dependents  Tenure Months  Phone Service  Paperless Billing  ...  \
# 3580           1      -1.156054              1                  1  ...
# 2364           0      -1.278321              1                  0  ...
# 6813           0       1.615327              1                  0  ...
# 789            0      -0.381697              1                  1  ...
# 561            0      -1.196809              1                  0  ...
#
#       Online Backup_No  Online Backup_Yes  Device Protection_No  \
# 3580                 0                  0                     0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (30,20))
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\3433675093.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # droping highly corelated veriable

# %%
x_test = x_test.drop(['MultipleLines_No','Online Security_No','Online Backup_No','Device Protection_No','TechSupport_No',
                       'StreamingTV_No','StreamingMovies_No'], 1)
x_train = x_train.drop(['MultipleLines_No','Online Security_No','Online Backup_No','Device Protection_No','TechSupport_No',
                         'StreamingTV_No','StreamingMovies_No'], 1)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\640632938.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_test = x_test.drop(['MultipleLines_No','Online Security_No','Online Backup_No','Device Protection_No','TechSupport_No',
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\640632938.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_train = x_train.drop(['MultipleLines_No','Online Security_No','Online Backup_No','Device Protection_No','TechSupport_No',

# %%
plt.figure(figsize=(20,10))
sns.heatmap(x_train.corr(),annot=True)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\3903083543.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(x_train.corr(),annot=True)
# <Axes: >

# %%
x_test=x_test.drop(['Tenure Months'],axis=1)

# %%
x_train=x_train.drop(['Tenure Months'],axis=1)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(x_train.corr(),annot=True)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\3903083543.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(x_train.corr(),annot=True)
# <Axes: >

# %%
x_test=x_test.drop(['Monthly Charges'],axis=1)
x_train=x_train.drop(['Monthly Charges'],axis=1)

# %% [markdown]
# # building model

# %%
import statsmodels.api as sm

# %%
x_train_sm=sm.add_constant(x_train)

# %%
x_train_sm.head()
# Out:
#       Count  Zip Code  Latitude  Longitude Senior Citizen  Partner  \
# 3580      1     93254 -0.545284   0.026094             No        1
# 2364      1     93240 -0.280890   0.622321             No        0
# 6813      1     90505 -1.011596   0.677289             No        1
# 789       1     95636  0.948415  -0.332437             No        1
# 561       1     92338 -0.648318   1.724348             No        0
#
#       Dependents  Phone Service  Paperless Billing  Churn Score  ...  \
# 3580           1              1                  1           26  ...
# 2364           0              1                  0           21  ...
# 6813           0              1                  0           24  ...
# 789            0              1                  1           83  ...
# 561            0              1                  0           83  ...
#
#       Internet Service_No  Contract_One year  Contract_Two year  \
# 3580                    1                  0                  0
# ...

# %%
x_train_sm['Senior Citizen'] = x_train_sm['Senior Citizen'].map({'Yes': 1, 'No': 0})

# %%
x_train_sm['Senior Citizen'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
model1=sm.GLM(y_train,x_train_sm,family = sm.families.Binomial())
model1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            Churn Value   No. Observations:                 4930
# Model:                            GLM   Df Residuals:                     4904
# Model Family:                Binomial   Df Model:                           25
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -897.29
# Date:                Thu, 22 Feb 2024   Deviance:                       1794.6
# Time:                        21:47:31   Pearson chi2:                 2.18e+03
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.5489
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# # feature selection using RFE

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()

# %%
x_train['Senior Citizen']=x_train['Senior Citizen'].map({'Yes':1,'No':0})

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4930 entries, 3580 to 2732
# Data columns (total 26 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Count                                   4930 non-null   int64
#  1   Zip Code                                4930 non-null   int64
#  2   Latitude                                4930 non-null   float64
#  3   Longitude                               4930 non-null   float64
#  4   Senior Citizen                          4930 non-null   int64
#  5   Partner                                 4930 non-null   int64
#  6   Dependents                              4930 non-null   int64
#  7   Phone Service                           4930 non-null   int64
#  8   Paperless Billing                       4930 non-null   int64
#  9   Churn Score                             4930 non-null   int64
# ...

# %%
logreg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(x_train,y_train)

# %%
from sklearn.feature_selection import RFE
rfe = RFE(estimator=logreg, n_features_to_select=15)
rfe=rfe.fit(x_train,y_train)
# Out:
# C:\Users\Sony\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Sony\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False False False  True False  True False  True  True False False
#   True  True False  True  True  True  True  True  True  True False  True
#   True False]
# [12  7 10 11  1  2  1  9  1  1  6  8  1  1  4  1  1  1  1  1  1  1  5  1
#   1  3]

# %%
list(zip(x_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('Count', False, 12),
#  ('Zip Code', False, 7),
#  ('Latitude', False, 10),
#  ('Longitude', False, 11),
#  ('Senior Citizen', True, 1),
#  ('Partner', False, 2),
#  ('Dependents', True, 1),
#  ('Phone Service', False, 9),
#  ('Paperless Billing', True, 1),
#  ('Churn Score', True, 1),
#  ('CLTV', False, 6),
#  ('Gender_Male', False, 8),
#  ('Payment Method_Credit card (automatic)', True, 1),
#  ('Payment Method_Electronic check', True, 1),
#  ('Payment Method_Mailed check', False, 4),
#  ('Internet Service_Fiber optic', True, 1),
#  ('Internet Service_No', True, 1),
#  ('Contract_One year', True, 1),
#  ('Contract_Two year', True, 1),
#  ('MultipleLines_Yes', True, 1),
#  ('Online Security_Yes', True, 1),
#  ('Online Backup_Yes', True, 1),
#  ('Device Protection_Yes', False, 5),
#  ('TechSupport_Yes', True, 1),
#  ('StreamingTV_Yes', True, 1),
#  ('StreamingMovies_Yes', False, 3)]

# %%
col=x_train.columns[rfe.support_]         # filtering

# %%
x_train=x_train[col]
# Out:
#       Senior Citizen  Dependents  Paperless Billing  Churn Score  \
# 3580               0           1                  1           26
# 2364               0           0                  0           21
# 6813               0           0                  0           24
# 789                0           0                  1           83
# 561                0           0                  0           83
# ...              ...         ...                ...          ...
# 4931               1           0                  1           71
# 3264               1           0                  1           33
# 1653               0           0                  0           89
# 2607               0           0                  0           51
# 2732               0           0                  1           78
#
#       Payment Method_Credit card (automatic)  Payment Method_Electronic check  \
# 3580                                       0                                1
# ...

# %%
x_train=x_train[col]

# %%
len(x_train.columns)
# Out:
# 15

# %% [markdown]
# # acess the model

# %%
x_train_sm=sm.add_constant(x_train)

# %%
x_train_sm
# Out:
#       const  Senior Citizen  Dependents  Paperless Billing  Churn Score  \
# 3580    1.0               0           1                  1           26
# 2364    1.0               0           0                  0           21
# 6813    1.0               0           0                  0           24
# 789     1.0               0           0                  1           83
# 561     1.0               0           0                  0           83
# ...     ...             ...         ...                ...          ...
# 4931    1.0               1           0                  1           71
# 3264    1.0               1           0                  1           33
# 1653    1.0               0           0                  0           89
# 2607    1.0               0           0                  0           51
# 2732    1.0               0           0                  1           78
#
#       Payment Method_Credit card (automatic)  Payment Method_Electronic check  \
# ...

# %%
model2=sm.GLM(y_train,x_train_sm,family=sm.families.Binomial())
model2.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            Churn Value   No. Observations:                 4930
# Model:                            GLM   Df Residuals:                     4914
# Model Family:                Binomial   Df Model:                           15
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -899.89
# Date:                Thu, 22 Feb 2024   Deviance:                       1799.8
# Time:                        23:21:51   Pearson chi2:                 2.18e+03
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.5484
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# # checking VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['feature']=x_train.columns

# %%
vif
# Out:
#                                    feature
# 0                           Senior Citizen
# 1                               Dependents
# 2                        Paperless Billing
# 3                              Churn Score
# 4   Payment Method_Credit card (automatic)
# 5          Payment Method_Electronic check
# 6             Internet Service_Fiber optic
# 7                      Internet Service_No
# 8                        Contract_One year
# 9                        Contract_Two year
# 10                       MultipleLines_Yes
# 11                     Online Security_Yes
# 12                       Online Backup_Yes
# 13                         TechSupport_Yes
# 14                         StreamingTV_Yes

# %%
vif['VIF']=[variance_inflation_factor(x_train.values,i) for i in range (0,len(vif))]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by='VIF',ascending=False)
vif
# Out:
#                                    feature   VIF
# 3                              Churn Score  4.80
# 6             Internet Service_Fiber optic  2.95
# 2                        Paperless Billing  2.78
# 9                        Contract_Two year  2.28
# 14                         StreamingTV_Yes  2.26
# 7                      Internet Service_No  2.25
# 10                       MultipleLines_Yes  2.15
# 5          Payment Method_Electronic check  2.13
# 12                       Online Backup_Yes  1.96
# 13                         TechSupport_Yes  1.96
# 11                     Online Security_Yes  1.82
# 8                        Contract_One year  1.63
# 4   Payment Method_Credit card (automatic)  1.51
# 1                               Dependents  1.37
# 0                           Senior Citizen  1.34

# %%
x_train=x_train.drop('MultipleLines_Yes',1)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\1398060622.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_train=x_train.drop('MultipleLines_Yes',1)

# %%
x_train_sm=sm.add_constant(x_train)
model3=sm.GLM(y_train,x_train_sm,family=sm.families.Binomial())
model3.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            Churn Value   No. Observations:                 4930
# Model:                            GLM   Df Residuals:                     4915
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -901.76
# Date:                Thu, 22 Feb 2024   Deviance:                       1803.5
# Time:                        23:37:16   Pearson chi2:                 2.19e+03
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.5480
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = x_train.columns
vif['VIF'] = [variance_inflation_factor(x_train.values, i) for i in range(0,len(vif))]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                   Features   VIF
# 3                              Churn Score  4.79
# 2                        Paperless Billing  2.77
# 6             Internet Service_Fiber optic  2.69
# 7                      Internet Service_No  2.25
# 13                         StreamingTV_Yes  2.25
# 9                        Contract_Two year  2.22
# 5          Payment Method_Electronic check  2.13
# 12                         TechSupport_Yes  1.96
# 11                       Online Backup_Yes  1.95
# 10                     Online Security_Yes  1.82
# 8                        Contract_One year  1.62
# 4   Payment Method_Credit card (automatic)  1.50
# 1                               Dependents  1.37
# 0                           Senior Citizen  1.33

# %%
x_train=x_train.drop('Senior Citizen',1)
# Out:
# C:\Users\Sony\AppData\Local\Temp\ipykernel_13212\4175219542.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_train=x_train.drop('Senior Citizen',1)

# %%
x_train_sm=sm.add_constant(x_train)
model4=sm.GLM(y_train,x_train_sm,family=sm.families.Binomial())
regression_result=model4.fit()

# %%
regression_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            Churn Value   No. Observations:                 4930
# Model:                            GLM   Df Residuals:                     4916
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -902.25
# Date:                Fri, 23 Feb 2024   Deviance:                       1804.5
# Time:                        00:07:37   Pearson chi2:                 2.19e+03
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.5479
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
# Getting the predicted values on the train set
y_train_pred = res.predict(X_train_sm)
y_train_pred[:10]

# %%
y_train_pred=regression_result.predict(x_train_sm)
y_train_pred[:3]
# Out:
# 3580    0.000018
# 2364    0.000012
# 6813    0.000001
# dtype: float64

# %%
y_train_pred=y_train_pred.values.reshape(-1)
y_train_pred
# Out:
# array([1.76699530e-05, 1.16620053e-05, 1.17024121e-06, ...,
#        9.63180165e-01, 2.36235819e-04, 7.93427961e-01])
